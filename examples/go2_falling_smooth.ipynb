# %%
import MuJoCo as mj

# %%
"""
Constants
"""

N = Int(1.5e4)
Δt = 1e-4
Z_OFFSET = 0.5
# Out:
# 0.5

# %%
"""
Load model
"""

# Get model and data
model = mj.load_model("unitree_go2/scene_smooth.xml")
data = mj.init_data(model)
mj.reset!(model, data)

# Set sim time step
model.opt.timestep = Δt

# Get joint names
for i = 1 : model.nq
    ptr = mj.mj_id2name(model, mj.mjOBJ_JOINT, i)
    if ptr != C_NULL
        name = unsafe_string(ptr)
    else
        name = "unnamed"
    end
    println("Joint $i: $name")
end

# %%
"""
Simulate
"""

# State history
xhist = zeros(model.nq + model.nv + model.na, N)

# Add height offset to initial conditions
mj.reset!(model, data)
data.qpos[3] += Z_OFFSET

# Simulate
mj.forward!(model, data)
for k = 1:N
    xhist[:,k] .= mj.get_physics_state(model, data)
    mj.step!(model, data)
end

# %%
"""
Visualize state history
"""

mj.init_visualiser()
mj.visualise!(model, data, trajectories=[xhist])
